# %%
#ELIGOS_normalC

#basecalling
guppy_basecaller -i IVT_normalC_fast5 -s IVT_normalC_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"
guppy_basecaller -i IVT_m5C_fast5 -s IVT_m5C_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"

#multi to single
multi_to_single_fast5 -i IVT_normalC_guppy -s IVT_normalC_guppy_single -t 40 --recursive 
multi_to_single_fast5 -i IVT_m5C_guppy -s IVT_m5C_guppy_single -t 40 --recursive 

#resquiggle
tombo resquiggle --overwrite --basecall-group Basecall_1D_000 IVT_normalC_guppy_single /root/sunxh/data/fna/ELIGOS_reference.fa --processes 20 --fit-global-scale --include-event-stdev
tombo resquiggle --overwrite --basecall-group Basecall_1D_000 IVT_m5c_guppy_single /root/sunxh/data/fna/ELIGOS_reference.fa --processes 40 --fit-global-scale --include-event-stdev

cat IVT_normalC_guppy/pass/*.fastq >IVT_normalC.fastq
cat IVT_m5C_guppy/pass/*.fastq >IVT_m5C.fastq

#map reads to reference
minimap2 -ax map-ont  /root/sunxh/data/fna/ELIGOS_reference.fa IVT_normalC.fastq > IVT_normalC.sam
minimap2 -ax map-ont  /root/sunxh/data/fna/ELIGOS_reference.fa IVT_m5C.fastq > IVT_m5C.sam

#feature extraction
python /root/sunxh/WaveCrossMamba/utils/fast5_signal.py -p 40 --fast5 IVT_normalC_guppy_single --reference /root/sunxh/data/fna/ELIGOS_reference.fa --sam IVT_normalC.sam --output IVT_normalC.signal.tsv --clip 10
python /root/sunxh/WaveCrossMamba/utils/fast5_signal.py -p 40 --fast5 IVT_m5C_guppy_single --reference /root/sunxh/data/fna/ELIGOS_reference.fa --sam IVT_m5C.sam --output IVT_m5C.signal.tsv --clip 10

python scripts/extract_feature_from_signal.py  --signal_file IVT_normalC.signal.tsv --clip 10 --output IVT_normalC.feature.tsv --motif NNCNN
python scripts/extract_feature_from_signal.py  --signal_file IVT_m5C.signal.tsv --clip 10 --output IVT_normalC.feature.tsv --motif NNCNN



#ELIGOS_normalA

#basecalling
guppy_basecaller -i IVT_normalA_fast5 -s IVT_normalA_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device cuda:1
guppy_basecaller -i IVT_m6A_fast5 -s IVT_m6A_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device cuda:1

#multi to single
multi_to_single_fast5 -i IVT_normalA_guppy -s IVT_normalA_guppy_single -t 40 --recursive 
multi_to_single_fast5 -i IVT_m6A_guppy -s IVT_m6A_guppy_single -t 40 --recursive 

#resquiggle
tombo resquiggle --overwrite --basecall-group Basecall_1D_000 IVT_normalA_guppy_single /root/sunxh/data/fna/ELIGOS_reference.fa --processes 20 --fit-global-scale --include-event-stdev
tombo resquiggle --overwrite --basecall-group Basecall_1D_000 IVT_m6A_guppy_single /root/sunxh/data/fna/ELIGOS_reference.fa --processes 40 --fit-global-scale --include-event-stdev

cat IVT_normalA_guppy/pass/*.fastq >IVT_normalA.fastq
cat IVT_m6A_guppy/pass/*.fastq >IVT_m6A.fastq

#map reads to reference
minimap2 -ax map-ont  /root/sunxh/data/fna/ELIGOS_reference.fa IVT_normalA.fastq > IVT_normalA.sam
minimap2 -ax map-ont  /root/sunxh/data/fna/ELIGOS_reference.fa IVT_m6A.fastq > IVT_m6A.sam

#feature extraction
python /root/sunxh/WaveCrossMamba/utils/fast5_signal.py -p 40 --fast5 IVT_normalA_guppy_single --reference /root/sunxh/data/fna/ELIGOS_reference.fa --sam IVT_normalA.sam --output IVT_normalA.signal.tsv --clip 10
python /root/sunxh/WaveCrossMamba/utils/fast5_signal.py -p 40 --fast5 IVT_m6A_guppy_single --reference /root/sunxh/data/fna/ELIGOS_reference.fa --sam IVT_m6A.sam --output IVT_m6A.signal.tsv --clip 10

python scripts/extract_feature_from_signal.py  --signal_file IVT_normalA.signal.tsv --clip 10 --output IVT_normalA.feature.tsv --motif NNANN
python scripts/extract_feature_from_signal.py  --signal_file IVT_m6A.signal.tsv --clip 10 --output IVT_normalA.feature.tsv --motif NNANN

# %%
# human cell K562

guppy_basecaller -i /root/sunxh/WaveCrossMamba/human_cell/mnt/volume1/GIS_K562_directRNA_Rep5-Run1/fast5_pass -s /root/sunxh/WaveCrossMamba/human_cell/K562_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"

multi_to_single_fast5 -i /root/sunxh/WaveCrossMamba/human_cell/K562_guppy -s /root/sunxh/WaveCrossMamba/human_cell/K562_guppy_single -t 20 --recursive

tombo resquiggle --overwrite --basecall-group Basecall_1D_000 /root/sunxh/WaveCrossMamba/human_cell/K562_guppy_single /root/sunxh/data/fna/GRCh38_latest_rna.fna --processes 20 --fit-global-scale --include-event-stdev

cat /root/sunxh/WaveCrossMamba/human_cell/K562_guppy/pass/*.fastq > /root/sunxh/WaveCrossMamba/human_cell/K562.fastq

minimap2 -ax map-ont /root/sunxh/data/fna/GRCh38_latest_rna.fna /root/sunxh/WaveCrossMamba/human_cell/K562.fastq > /root/sunxh/WaveCrossMamba/human_cell/K562.sam

python /root/sunxh/WaveCrossMamba/utils/raw_fast5_current_signal.py -p 20 --fast5 /root/sunxh/WaveCrossMamba/human_cell/K562_guppy_single --reference /root/sunxh/data/fna/GRCh38_latest_rna.fna --sam /root/sunxh/WaveCrossMamba/human_cell/K562.sam --output /root/sunxh/WaveCrossMamba/human_cell/K562.signal.tsv --clip=10

python /root/sunxh/WaveCrossMamba/utils/raw_signal-feature.py --signal_file /root/sunxh/WaveCrossMamba/human_cell/K562.signal.tsv --clip 10 --output /root/sunxh/WaveCrossMamba/human_cell/K562.feature.tsv --motif RRACH

# %%
# HEK293T-WT
guppy_basecaller -i //root/sunxh/HEK293T/fast5/fast5_pass/ -s /root/sunxh/HEK293T/fast5/HEK293T_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"
multi_to_single_fast5 -i /root/sunxh/HEK293T/fast5/HEK293T_guppy -s /root/sunxh/HEK293T/fast5/HEK293T_guppy_single -t 20 --recursive
tombo resquiggle --overwrite --basecall-group Basecall_1D_000 /root/sunxh/HEK293T/fast5/HEK293T_guppy_single /root/sunxh/data/fna/GRCh38_latest_rna.fna --processes 20 --fit-global-scale --include-event-stdev
cat /root/sunxh/HEK293T/fast5/HEK293T_guppy/pass/*.fastq >HEK293T_guppy.fastq
minimap2 -ax map-ont /root/sunxh/data/fna/GRCh38_latest_rna.fna HEK293T_guppy.fastq > HEK293T_guppy.sam
python /root/sunxh/WaveCrossMamba/utils/raw_fast5_current_signal.py --fast5 /root/sunxh/HEK293T/fast5/HEK293T_guppy_single -o /root/sunxh/HEK293T/hek293t-wt.signal.tsv --sam HEK293T_guppy.sam -r /root/sunxh/data/fna/GRCh38_latest_rna.fna



guppy_basecaller -i /root/sunxh/data/HEK293T-Mettl3-KO-rep3 -s /root/sunxh/data/HEK293T-Mettl3-KO-rep3_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"
multi_to_single_fast5 -i /root/sunxh/data/HEK293T-Mettl3-KO-rep3_guppy -s /root/sunxh/data/HEK293T-Mettl3-KO-rep3_guppy_single -t 40 --recursive
tombo resquiggle --overwrite --basecall-group Basecall_1D_000 /root/sunxh/data/HEK293T-Mettl3-KO-rep3_guppy_single /root/sunxh/data/fna/GRCh38_latest_rna.fna --processes 20 --fit-global-scale --include-event-stdev
cat /root/sunxh/data/HEK293T-Mettl3-KO-rep3_guppy/pass/*.fastq >ko-rep3.fastq
minimap2 -ax map-ont /root/sunxh/data/fna/GRCh38_latest_rna.fna ko-rep3.fastq > ko-rep3.sam
python /root/sunxh/WaveCrossMamba/utils/fast5_signal.py --fast5 /root/sunxh/data/HEK293T-Mettl3-KO-rep3_guppy_single -o /root/sunxh/data/hek293t-ko.signal.tsv --sam ko-rep3.sam -r /root/sunxh/data/fna/GRCh38_latest_rna.fna

# %%
# human cell MCF7

guppy_basecaller -i /root/sunxh/WaveCrossMamba/human_cell/mnt/projectsInstanceStore1/chenying/ena_upload/fast5/SGNex_MCF7_directRNA_replicate3_run1 -s /root/sunxh/WaveCrossMamba/human_cell/MCF7_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"

multi_to_single_fast5 -i /root/sunxh/WaveCrossMamba/human_cell/MCF7_guppy/ -s /root/sunxh/WaveCrossMamba/human_cell/MCF7_guppy_single -t 20 --recursive

tombo resquiggle --overwrite --basecall-group Basecall_1D_000 /root/sunxh/WaveCrossMamba/human_cell/MCF7_guppy_single /root/sunxh/data/fna/GRCh38_latest_rna.fna --processes 20 --fit-global-scale --include-event-stdev

cat /root/sunxh/WaveCrossMamba/human_cell/MCF7_guppy/pass/*.fastq > /root/sunxh/WaveCrossMamba/human_cell/MCF7.fastq

minimap2 -ax map-ont /root/sunxh/data/fna/GRCh38_latest_rna.fna /root/sunxh/WaveCrossMamba/human_cell/MCF7.fastq > /root/sunxh/WaveCrossMamba/human_cell/MCF7.sam   

python /root/sunxh/WaveCrossMamba/utils/raw_fast5_current_signal.py -p 20 --fast5 /root/sunxh/WaveCrossMamba/human_cell/MCF7_guppy_single --reference /root/sunxh/data/fna/GRCh38_latest_rna.fna --sam /root/sunxh/WaveCrossMamba/human_cell/MCF7.sam --output /root/sunxh/WaveCrossMamba/human_cell/MCF7.signal.tsv --clip=10

python /root/sunxh/WaveCrossMamba/utils/raw_signal-feature.py --signal_file /root/sunxh/WaveCrossMamba/human_cell/MCF7.signal.tsv --clip 10 --output /root/sunxh/WaveCrossMamba/human_cell/MCF7.feature.tsv --motif NNANN

# %%
# human cell hct116

guppy_basecaller -i /root/sunxh/WaveCrossMamba/human_cell/GIS_Hct116_directRNA_Rep2-Run4/fast5_pass -s /root/sunxh/WaveCrossMamba/human_cell/hct116_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"

multi_to_single_fast5 -i /root/sunxh/WaveCrossMamba/human_cell/hct116_guppy -s /root/sunxh/WaveCrossMamba/human_cell/hct116_guppy_single -t 20 --recursive

tombo resquiggle --overwrite --basecall-group Basecall_1D_000 /root/sunxh/WaveCrossMamba/human_cell/hct116_guppy_single /root/sunxh/data/fna/GRCh38_latest_rna.fna --processes 20 --fit-global-scale --include-event-stdev --ignore-read-locks

cat /root/sunxh/WaveCrossMamba/human_cell/hct116_guppy/pass/*.fastq > /root/sunxh/WaveCrossMamba/human_cell/hct116.fastq

minimap2 -ax map-ont /root/sunxh/data/fna/GRCh38_latest_rna.fna /root/sunxh/WaveCrossMamba/human_cell/hct116.fastq > /root/sunxh/WaveCrossMamba/human_cell/hct116.sam   

python /root/sunxh/WaveCrossMamba/utils/raw_fast5_current_signal.py -p 20 --fast5 /root/sunxh/WaveCrossMamba/human_cell/hct116_guppy_single --reference /root/sunxh/data/fna/GRCh38_latest_rna.fna --sam /root/sunxh/WaveCrossMamba/human_cell/hct116.sam --output /root/sunxh/WaveCrossMamba/human_cell/hct116.signal.tsv --clip=10

python /root/sunxh/WaveCrossMamba/utils/raw_signal-feature.py --signal_file /root/sunxh/WaveCrossMamba/human_cell/hct116.signal.tsv --clip 10 --output /root/sunxh/WaveCrossMamba/human_cell/hct116.feature.tsv --motif NNANN

# %%
# human cell A549

guppy_basecaller -i /root/sunxh/WaveCrossMamba/human_cell/GIS_A549_directRNA_Rep6-Run1/fast5_pass -s /root/sunxh/WaveCrossMamba/human_cell/a549_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"

multi_to_single_fast5 -i /root/sunxh/WaveCrossMamba/human_cell/a549_guppy -s /root/sunxh/WaveCrossMamba/human_cell/a549_guppy_single -t 20 --recursive

tombo resquiggle --overwrite --basecall-group Basecall_1D_000 /root/sunxh/WaveCrossMamba/human_cell/a549_guppy_single /root/sunxh/data/fna/GRCh38_latest_rna.fna --processes 20 --fit-global-scale --include-event-stdev --ignore-read-locks

cat /root/sunxh/WaveCrossMamba/human_cell/a549_guppy/pass/*.fastq > /root/sunxh/WaveCrossMamba/human_cell/a549.fastq

minimap2 -ax map-ont /root/sunxh/data/fna/GRCh38_latest_rna.fna /root/sunxh/WaveCrossMamba/human_cell/a549.fastq > /root/sunxh/WaveCrossMamba/human_cell/a549.sam   

python /root/sunxh/WaveCrossMamba/utils/raw_fast5_current_signal.py -p 20 --fast5 /root/sunxh/WaveCrossMamba/human_cell/a549_guppy_single --reference /root/sunxh/data/fna/GRCh38_latest_rna.fna --sam /root/sunxh/WaveCrossMamba/human_cell/a549.sam --output /root/sunxh/WaveCrossMamba/human_cell/a549.signal.tsv --clip=10

python /root/sunxh/WaveCrossMamba/utils/raw_signal-feature.py --signal_file /root/sunxh/WaveCrossMamba/human_cell/a549.signal.tsv --clip 10 --output /root/sunxh/WaveCrossMamba/human_cell/a549.feature.tsv --motif NNANN

# %%
# human cell hepg2

guppy_basecaller -i /root/sunxh/WaveCrossMamba/human_cell/mnt/projects/pratanwanich/nanopore/GIS_HepG2_directRNA_Rep6-Run1/fast5_pass -s /root/sunxh/WaveCrossMamba/human_cell/hepg2_guppy --num_callers 20 --recursive --fast5_out --config rna_r9.4.1_70bps_hac.cfg --device "cuda:0 cuda:1 cuda:2 cuda:3"

multi_to_single_fast5 -i /root/sunxh/WaveCrossMamba/human_cell/hepg2_guppy -s /root/sunxh/WaveCrossMamba/human_cell/hepg2_guppy_single -t 20 --recursive

tombo resquiggle --overwrite --basecall-group Basecall_1D_000 /root/sunxh/WaveCrossMamba/human_cell/hepg2_guppy_single /root/sunxh/data/fna/GRCh38_latest_rna.fna --processes 20 --fit-global-scale --include-event-stdev --ignore-read-locks

cat /root/sunxh/WaveCrossMamba/human_cell/hepg2_guppy/pass/*.fastq > /root/sunxh/WaveCrossMamba/human_cell/hepg2.fastq

minimap2 -ax map-ont /root/sunxh/data/fna/GRCh38_latest_rna.fna /root/sunxh/WaveCrossMamba/human_cell/hepg2.fastq > /root/sunxh/WaveCrossMamba/human_cell/hepg2.sam   

python /root/sunxh/WaveCrossMamba/utils/raw_fast5_current_signal.py -p 20 --fast5 /root/sunxh/WaveCrossMamba/human_cell/hepg2_guppy_single --reference /root/sunxh/data/fna/GRCh38_latest_rna.fna --sam /root/sunxh/WaveCrossMamba/human_cell/hepg2.sam --output /root/sunxh/WaveCrossMamba/human_cell/hepg2.signal.tsv --clip=10

python /root/sunxh/WaveCrossMamba/utils/raw_signal-feature.py --signal_file /root/sunxh/WaveCrossMamba/human_cell/hepg2.signal.tsv --clip 10 --output /root/sunxh/WaveCrossMamba/human_cell/hepg2.feature.tsv --motif NNANN
