# %%
# m6a
dorado basecaller /mnt/sunxh/models/rna004_130bps_sup@v5.1.0 \
/mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m6A/ \
-x cuda:0 --emit-moves --emit-sam \
-o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/m6A/ \
--reference /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
--mm2-opts "-x map-ont"

uncalled4 align --ref /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
-p 4 --reads /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m6A/ \
--bam-in /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/m6A/*.sam \
--rna -o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/m6A.bam

python utils/uncalled4_pod5_to_signal.py \
--pod5 /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m6A/ \
--bam  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/m6A.bam \
--out  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/m6A_signal.tsv \
--ref  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/m6A_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/m6A.test.tsv \
--motif NNANN

# %%
#m5c
dorado basecaller /mnt/sunxh/models/rna004_130bps_sup@v5.1.0 \
/mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m5C/ \
-x cuda:0 --emit-moves --emit-sam \
-o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/m5C/ \
--reference /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
--mm2-opts "-x map-ont"


uncalled4 align --ref /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
-p 16 --reads /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m5C/ \
--bam-in /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/m5C/*.sam \
--rna -o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/m5C.bam

python utils/uncalled4_pod5_to_signal.py \
--pod5 /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m5C/ \
--bam  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/m5C.bam \
--out  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/m5C_signal.tsv \
--ref  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/m5C_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/m5C_features.tsv \
--motif NNCNN

# %%
#m5u
dorado basecaller /mnt/sunxh/models/rna004_130bps_sup@v5.1.0 \
/mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m5U/ \
-x cuda:0 --emit-moves --emit-sam \
-o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/m5U/ \
--reference /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
--mm2-opts "-x map-ont"


uncalled4 align --ref /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
-p 16 --reads /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m5U/ \
--bam-in /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/m5U/*.sam \
--rna -o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/m5U.bam

python utils/uncalled4_pod5_to_signal.py \
--pod5 /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m5U/ \
--bam  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/m5U.bam \
--out  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/m5U_signal.tsv \
--ref  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/m5U_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/m5U_features.tsv \
--motif NNTNN

# %%
# ac4C
dorado basecaller /mnt/sunxh/models/rna004_130bps_sup@v5.1.0 \
/mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/ac4C/ \
--emit-moves --emit-sam \
-o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/ac4C/ \
--reference /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
--mm2-opts "-x map-ont"


uncalled4 align --ref /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
-p 16 --reads /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/ac4C/ \
--bam-in /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/ac4C/*.sam \
--rna -o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/ac4C.bam

python utils/uncalled4_pod5_to_signal.py \
--pod5 /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/ac4C/ \
--bam  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/ac4C.bam \
--out  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/ac4C_signal.tsv \
--ref  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/ac4C_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/ac4C_features.tsv \
--motif NNCNN

# %%
#5hmc
dorado basecaller /mnt/sunxh/models/rna004_130bps_sup@v5.1.0 \
/mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/5hmC/ \
-x cuda:0 --emit-moves --emit-sam \
-o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/5hmC/ \
--reference /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
--mm2-opts "-x map-ont"


uncalled4 align --ref /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
-p 16 --reads /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/5hmC/ \
--bam-in /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/5hmC/*.sam \
--rna -o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/5hmC.bam

python utils/uncalled4_pod5_to_signal.py \
--pod5 /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/5hmC/ \
--bam  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/5hmC.bam \
--out  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/5hmC_signal.tsv \
--ref  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/5hmC_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/5hmC_features.tsv \
--motif NNCNN

# %%
#m1Y
dorado basecaller /mnt/sunxh/models/rna004_130bps_sup@v5.1.0 \
/mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m1Y/ \
-x cuda:0 --emit-moves --emit-sam \
-o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/m1Y/ \
--reference /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
--mm2-opts "-x map-ont"

uncalled4 align --ref /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
-p 16 --reads /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m1Y/ \
--bam-in /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/m1Y/*.sam \
--rna -o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/m1Y.bam 

python utils/uncalled4_pod5_to_signal.py \
--pod5 /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/m1Y/ \
--bam  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/m1Y.bam \
--out  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/m1Y_signal.tsv \
--ref  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/m1Y_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/m1Y_features.tsv \
--motif NNTNN

# %%
# Y
dorado basecaller /mnt/sunxh/models/rna004_130bps_sup@v5.1.0 \
/mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/Y \
-x cuda:0 --emit-moves --emit-sam \
-o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/Y/ \
--reference /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
--mm2-opts "-x map-ont"

uncalled4 align --ref /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
-p 16 --reads /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/Y/ \
--bam-in /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/Y/*.sam \
--rna -o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/Y.bam

python utils/uncalled4_pod5_to_signal.py \
--pod5 /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/Y/ \
--bam  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/Y.bam \
--out  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/Y_signal.tsv \
--ref  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/Y_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/Y_features.tsv \
--motif NNTNN

# %%
# unmod
dorado basecaller /mnt/sunxh/models/rna004_130bps_sup@v5.1.0 \
/mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/unmod/ \
-x cuda:0 --emit-moves --emit-sam \
-o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/unmod/ \
--reference /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
--mm2-opts "-x map-ont"


uncalled4 align --ref /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa \
-p 16 --reads /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/unmod/ \
--bam-in /mnt/sunxh/Datasets_RNA/curlcake_RNA004/sam/unmod/*.sam \
--rna -o /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/unmod.bam

python utils/uncalled4_pod5_to_signal.py \
--pod5 /mnt/sunxh/Datasets_RNA/curlcake_RNA004/fast5/unmod/ \
--bam  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/align/unmod.bam \
--out  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/unmod_signal.tsv \
--ref  /mnt/sunxh/Datasets_RNA/curlcake_RNA004/curlcake_reference.fa

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/unmod_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/unmodA.tsv \
--motif NNANN

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/unmod_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/unmodC.tsv \
--motif NNCNN

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/unmod_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/unmodG.tsv \
--motif NNGNN

python utils/uncalled4_signal_to_feature.py \
--signal /mnt/sunxh/Datasets_RNA/curlcake_RNA004/signal/unmod_signal.tsv \
--out    /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/unmodT.tsv \
--motif NNTNN

# %%
python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/m6A.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/m6A_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/m6A_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/m5C_features.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/m5c_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/m5c_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/m5U_features.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/m5u_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/m5u_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/ac4C_features.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/ac4c_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/ac4c_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/5hmC_features.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/hm5c_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/hm5c_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/Y_features.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/y_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/y_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/m1Y_features.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/m1y_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/m1y_test.tsv


python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/unmodA.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/normala_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/normala_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/unmodC.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/normalc_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/normalc_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/unmodG.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/normalg_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/normalg_test.tsv

python train_test_split.py \
--input_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/feature/unmodT.tsv \
--train_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/normalt_train.tsv \
--test_file /mnt/sunxh/Datasets_RNA/curlcake_RNA004/train_and_test/normalt_test.tsv
